# %%
import numpy as np
import pandas as pd
arquivo = pd.read_csv('C:/Users/anizio.silva/teste/wine_dataset.csv')
arquivo.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality style
# 0      9.4        5   red
# 1      9.8        5   red
# 2      9.8        5   red
# 3      9.8        6   red
# 4      9.4        5   red

# %%
arquivo['style'] = arquivo['style'].replace('red', 0)

# %%
arquivo['style'] = arquivo['style'].replace('white', 1)

# %%
arquivo
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  style
# 0         9.4        5      0
# 1         9.8        5      0
# 2         9.8        5      0
# 3         9.8        6      0
# 4         9.4        5      0
# ...       ...      ...    ...
# 6492     11.2        6      1
# 6493      9.6        5      1
# 6494      9.4        6      1
# 6495     12.8        7      1
# 6496     11.8        6      1
#
# [6497 rows x 13 columns]

# %%
y = arquivo['style']
x = arquivo.drop('style', axis = 1)
x
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 6492     11.2        6
# 6493      9.6        5
# 6494      9.4        6
# 6495     12.8        7
# 6496     11.8        6
#
# [6497 rows x 12 columns]

# %%
arquivo.shape
# Out:
# (6497, 13)

# %%
x.shape
# Out:
# (6497, 12)

# %%
y.shape
# Out:
# (6497,)

# %%
from sklearn.model_selection import train_test_split
 #criando conjuntos de dados de treino e teste, 0.3 é para usar 30% para teste e 30% para treino.
x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size = 0.3)

# %%
from sklearn.ensemble import ExtraTreesClassifier
#criação do modelo
modelo = ExtraTreesClassifier()
modelo.fit(x_treino,y_treino)

#imprimindo resultado
resultado = modelo.score(x_teste,y_teste)
print("Resultado:", resultado)
# Out:
# Resultado: 0.9953846153846154

# %%
y_teste[400:408]
# Out:
# 5586    1
# 1649    1
# 2617    1
# 2121    1
# 4750    1
# 2710    1
# 4202    1
# 4183    1
# Name: style, dtype: int64

# %%
x_teste[400:408]
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 5586            7.3              0.23         0.41            14.6      0.048
# 1649            7.2              0.19         0.31             1.6      0.062
# 2617            7.1              0.18         0.42             1.4      0.045
# 2121            6.9              0.25         0.40             1.3      0.038
# 4750            6.2              0.23         0.36            17.2      0.039
# 2710            8.0              0.18         0.37             1.3      0.040
# 4202            6.7              0.30         0.29             2.8      0.025
# 4183            6.8              0.18         0.30            12.8      0.062
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 5586                 73.0                 223.0  0.99863  3.16       0.71
# 1649                 31.0                 173.0  0.99170  3.35       0.44
# 2617                 47.0                 157.0  0.99160  2.95       0.31
# 2121                 22.0                 101.0  0.99010  3.03       0.39
# 4750                 37.0                 130.0  0.99946  3.23       0.43
# 2710                 15.0                  96.0  0.99120  3.06       0.61
# 4202                 37.0                 107.0  0.99159  3.31       0.63
# 4183                 19.0                 171.0  0.99808  3.00       0.52
#
#       alcohol  quality
# 5586      9.4        6
# 1649     11.7        6
# 2617     10.5        6
# 2121     11.4        6
# 4750      8.8        6
# 2710     12.1        6
# 4202     11.3        7
# 4183      9.0        7

# %%
previsoes = modelo.predict(x_teste[400:408])
previsoes
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 1], dtype=int64)
